# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
#print(type(r.text))
# Out:
# '[{"id":"13217355812","type":"CreateEvent","actor":{"id":61677679,"login":"kiranrouthuRS","display_login":"kiranrouthuRS","gravatar_id":"","url":"https://api.github.com/users/kiranrouthuRS","avatar_url":"https://avatars.githubusercontent.com/u/61677679?"},"repo":{"id":288102141,"name":"kiranrouthuRS/Powerbot-Client","url":"https://api.github.com/repos/kiranrouthuRS/Powerbot-Client"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-08-17T06:34:05Z"},{"id":"13217355816","type":"IssueCommentEvent","actor":{"id":26996169,"login":"uandco","display_login":"uandco","gravatar_id":"","url":"https://api.github.com/users/uandco","avatar_url":"https://avatars.githubusercontent.com/u/26996169?"},"repo":{"id":38675392,"name":"frctl/fractal","url":"https://api.github.com/repos/frctl/fractal"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/frctl/fractal/issues/645","repository_url":"https://api.github.com/repos/frctl/fractal","labels_url":"https://api.github.com/repos/frctl/fractal/issues/645/labels{/name}","comments_url":"https://api.github.com/repos/frctl/fractal/issues/645/comments","events_url":"https://api.github.com/repos/frctl/fractal/issues/645/events","html_url":"https://github.com/frctl/fractal/issues/645","id":672532818,"node_id":"MDU6SXNzdWU2NzI1MzI4MTg=","number":645,"title":"Twig component renders incorrectly from the docs","user":{"login":"uandco","id":26996169,"node_id":"MDQ6VXNlcjI2OTk2MTY5","avatar_url":"https://avatars2.githubusercontent.com/u/26996169?v=4","gravatar_id":"","url":"https://api.github.com/users/uandco","html_url":"https://github.com/uandco","followers_url":"https://api.github.com/users/uandco/followers","following_url":"https://api.github.com/users/uandco/following{/other_user}","gists_url":"https://api.github.com/users/uandco/gists{/gist_id}","starred_url":"https://api.github.com/users/uandco/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/uandco/subscriptions","organizations_url":"https://api.github.com/users/uandco/orgs","repos_url":"https://api.github.com/users/uandco/repos","events_url":"https://api.github.com/users/uandco/events{/privacy}","received_events_url":"https://api.github.com/users/uandco/received_events","type":"User","site_admin":false},"labels":[{"id":233293012,"node_id":"MDU6TGFiZWwyMzMyOTMwMTI=","url":"https://api.github.com/repos/frctl/fractal/labels/bug","name":"bug","color":"fc2929","default":true,"description":null}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":6,"created_at":"2020-08-04T06:12:20Z","updated_at":"2020-08-17T06:34:05Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"<!--\\r\\nBefore submitting your issue, please ensure you have:\\r\\n    * Checked the Fractal documentation: https://fractal.build/guide\\r\\n    * Checked that your issue isn’t already filed: https://github.com/issues?utf8=%E2%9C%93&q=is%3Aissue+user%3Afrctl\\r\\n-->\\r\\n\\r\\n### Steps to reproduce the issue\\r\\n\\r\\n1. clone https://github.com/uandco/fractal-twig-issue\\r\\n2. run `npm install`\\r\\n3. run `fractal start --sync`\\r\\n\\r\\nThe navigation component shows up OK when viewed as a component or rendered via another component (I rendered it in the example component)\\r\\n\\r\\nThe rendering fails when rendered from the docs (HTML code is displayed). I tried to use the twig engine for docs too but get the same result.\\r\\n\\r\\n**Reproduces how often:**\\r\\n\\r\\n100%\\r\\n\\r\\n### Reduced test case\\r\\n\\r\\nhttps://github.com/uandco/fractal-twig-issue\\r\\n\\r\\n### Context\\r\\n\\r\\n-   Fractal version: 1.3.0\\r\\n-   Node version: 10.15.1\\r\\n-   OS: MacOS 10.14.6\\r\\n","performed_via_github_app":null},"comment":{"url":"https://api.github.com/repos/frctl/fractal/issues/comments/674689063","html_url":"https://github.com/frctl/fractal/issues/645#issuecomment-67468 ...

# %%
import json
json.loads(r.text)
#print(type(json.loads(r.text)))
# Out:
# [{'id': '13217355812',
#   'type': 'CreateEvent',
#   'actor': {'id': 61677679,
#    'login': 'kiranrouthuRS',
#    'display_login': 'kiranrouthuRS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kiranrouthuRS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61677679?'},
#   'repo': {'id': 288102141,
#    'name': 'kiranrouthuRS/Powerbot-Client',
#    'url': 'https://api.github.com/repos/kiranrouthuRS/Powerbot-Client'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355816',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 26996169,
#    'login': 'uandco',
#    'display_login': 'uandco',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/uandco',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26996169?'},
#   'repo': {'id': 38675392,
#    'name': 'frctl/fractal',
#    'url': 'https://api.github.com/repos/frctl/fractal'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/frctl/fractal/issues/645',
#     'repository_url': 'https://api.github.com/repos/frctl/fractal',
#     'labels_url': 'https://api.github.com/repos/frctl/fractal/issues/645/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/frctl/fractal/issues/645/comments',
#     'events_url': 'https://api.github.com/repos/frctl/fractal/issues/645/events',
#     'html_url': 'https://github.com/frctl/fractal/issues/645',
#     'id': 672532818,
#     'node_id': 'MDU6SXNzdWU2NzI1MzI4MTg=',
#     'number': 645,
#     'title': 'Twig component renders incorrectly from the docs',
#     'user': {'login': 'uandco',
#      'id': 26996169,
#      'node_id': 'MDQ6VXNlcjI2OTk2MTY5',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/26996169?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/uandco',
#      'html_url': 'https://github.com/uandco',
#      'followers_url': 'https://api.github.com/users/uandco/followers',
#      'following_url': 'https://api.github.com/users/uandco/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/uandco/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/uandco/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/uandco/subscriptions',
#      'organizations_url': 'https://api.github.com/users/uandco/orgs',
#      'repos_url': 'https://api.github.com/users/uandco/repos',
#      'events_url': 'https://api.github.com/users/uandco/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/uandco/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 233293012,
#       'node_id': 'MDU6TGFiZWwyMzMyOTMwMTI=',
#       'url': 'https://api.github.com/repos/frctl/fractal/labels/bug',
#       'name': 'bug',
#       'color': 'fc2929',
#       'default': True,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 6,
#     'created_at': '2020-08-04T06:12:20Z',
#     'updated_at': '2020-08-17T06:34:05Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '<!--\r\nBefore submitting your issue, please ensure you have:\r\n    * Checked the Fractal documentation: https://fractal.build/guide\r\n    * Checked that your issue isn’t already filed: https://github.com/issues?utf8=%E2%9C%93&q=is%3Aissue+user%3Afrctl\r\n-->\r\n\r\n### Steps to reproduce the issue\r\n\r\n1. clone https://github.com/uandco/fractal-twig-issue\r\n2. run `npm install`\r\n3. run `fractal start --sync`\r\n\r\nThe navigation component shows up OK when viewed as a component or rendered via another component (I rendered it in the example component)\r\n\r\nThe rendering fails when rendered from the docs (HTML code is displayed). I tried to use the twig engine for docs too but get the same result.\r\n\r\n**Reproduces how often:**\r\n\r\n100%\r\n\r\n### Reduced test case\r\n\r\nhttps://github.com/uandco/fractal-twig-issue\r\n\r\n### Context\r\n\r\n-   Fractal version: 1.3.0\r\n-   Node version: 10.15.1\r\n-   OS: MacOS 10.14.6\r\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/frctl/fractal/issues/comments/674689063',
#     'html_url': 'https://github.com/frctl/fractal/issues/645#issuecomment-674689063',
#     'issue_url': 'https://api.github.com/repos/frctl/fractal/issues/645',
#     'id': 674689063,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY3NDY4OTA2Mw==',
#     'user': {'login': 'uandco',
#      'id': 26996169,
#      'node_id': 'MDQ6VXNlcjI2OTk2MTY5',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/26996169?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/uandco',
#      'html_url': 'https://github.com/uandco',
#      'followers_url': 'https://api.github.com/users/uandco/followers',
#      'following_url': 'https://api.github.com/users/uandco/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/uandco/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/uandco/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/uandco/subscriptions',
#      'organizations_url': 'https://api.github.com/users/uandco/orgs',
#      'repos_url': 'https://api.github.com/users/uandco/repos',
#      'events_url': 'https://api.github.com/users/uandco/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/uandco/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-08-17T06:34:05Z',
#     'updated_at': '2020-08-17T06:34:05Z',
#     'author_association': 'NONE',
#     'body': '@mihkeleidast no worries. That seems like a good plan, please check if you can get a newer version of marked that fixes the issue you can see in my test repo. Cheers.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z',
#   'org': {'id': 13216321,
#    'login': 'frctl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/frctl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13216321?'}},
#  {'id': '13217355807',
#   'type': 'PushEvent',
#   'actor': {'id': 57128609,
#    'login': 'abspen1',
#    'display_login': 'abspen1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abspen1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57128609?'},
#   'repo': {'id': 287914162,
#    'name': 'abspen1/abspen1.github.io',
#    'url': 'https://api.github.com/repos/abspen1/abspen1.github.io'},
#   'payload': {'push_id': 5538891679,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/stars',
#    'head': '514a7bbb048d536bdc31ade8dcc226a14a5e26e0',
#    'before': '88f33cdd71b57f7e647b8391ad6edc9004791e43',
#    'commits': [{'sha': '514a7bbb048d536bdc31ade8dcc226a14a5e26e0',
#      'author': {'email': 'abspencer2097@gmail.com', 'name': 'abspen1'},
#      'message': 'finished 👍',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/abspen1/abspen1.github.io/commits/514a7bbb048d536bdc31ade8dcc226a14a5e26e0'}]},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355808',
#   'type': 'CreateEvent',
#   'actor': {'id': 1997874,
#    'login': 'StarNamer',
#    'display_login': 'StarNamer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/StarNamer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1997874?'},
#   'repo': {'id': 286878075,
#    'name': 'StarNamer/dactyl-keyboard',
#    'url': 'https://api.github.com/repos/StarNamer/dactyl-keyboard'},
#   'payload': {'ref': 'dev-Tsgzj',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Parameterized ergonomic keyboard',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355804',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 56339322,
#    'login': 'jaredl101',
#    'display_login': 'jaredl101',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jaredl101',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56339322?'},
#   'repo': {'id': 282949224,
#    'name': 'Asyncing-Ship/turtle_mountain',
#    'url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain'},
#   'payload': {'action': 'opened',
#    'number': 247,
#    'pull_request': {'url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls/247',
#     'id': 468621286,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDY4NjIxMjg2',
#     'html_url': 'https://github.com/Asyncing-Ship/turtle_mountain/pull/247',
#     'diff_url': 'https://github.com/Asyncing-Ship/turtle_mountain/pull/247.diff',
#     'patch_url': 'https://github.com/Asyncing-Ship/turtle_mountain/pull/247.patch',
#     'issue_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues/247',
#     'number': 247,
#     'state': 'open',
#     'locked': False,
#     'title': 'Notification router now sending the from info as well, cleaned up con…',
#     'user': {'login': 'jaredl101',
#      'id': 56339322,
#      'node_id': 'MDQ6VXNlcjU2MzM5MzIy',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/56339322?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jaredl101',
#      'html_url': 'https://github.com/jaredl101',
#      'followers_url': 'https://api.github.com/users/jaredl101/followers',
#      'following_url': 'https://api.github.com/users/jaredl101/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jaredl101/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jaredl101/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jaredl101/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jaredl101/orgs',
#      'repos_url': 'https://api.github.com/users/jaredl101/repos',
#      'events_url': 'https://api.github.com/users/jaredl101/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jaredl101/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '…sole logs in other routers so stuff isnt spamming the server logs anymore.',
#     'created_at': '2020-08-17T06:34:05Z',
#     'updated_at': '2020-08-17T06:34:05Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls/247/commits',
#     'review_comments_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls/247/comments',
#     'review_comment_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues/247/comments',
#     'statuses_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/statuses/e93d441f1e910d758ec3f7bbe2d8edef34346b93',
#     'head': {'label': 'Asyncing-Ship:jared',
#      'ref': 'jared',
#      'sha': 'e93d441f1e910d758ec3f7bbe2d8edef34346b93',
#      'user': {'login': 'Asyncing-Ship',
#       'id': 68861302,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY4ODYxMzAy',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/68861302?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Asyncing-Ship',
#       'html_url': 'https://github.com/Asyncing-Ship',
#       'followers_url': 'https://api.github.com/users/Asyncing-Ship/followers',
#       'following_url': 'https://api.github.com/users/Asyncing-Ship/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Asyncing-Ship/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Asyncing-Ship/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Asyncing-Ship/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Asyncing-Ship/orgs',
#       'repos_url': 'https://api.github.com/users/Asyncing-Ship/repos',
#       'events_url': 'https://api.github.com/users/Asyncing-Ship/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Asyncing-Ship/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 282949224,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyODI5NDkyMjQ=',
#       'name': 'turtle_mountain',
#       'full_name': 'Asyncing-Ship/turtle_mountain',
#       'private': False,
#       'owner': {'login': 'Asyncing-Ship',
#        'id': 68861302,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY4ODYxMzAy',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/68861302?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Asyncing-Ship',
#        'html_url': 'https://github.com/Asyncing-Ship',
#        'followers_url': 'https://api.github.com/users/Asyncing-Ship/followers',
#        'following_url': 'https://api.github.com/users/Asyncing-Ship/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Asyncing-Ship/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Asyncing-Ship/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Asyncing-Ship/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Asyncing-Ship/orgs',
#        'repos_url': 'https://api.github.com/users/Asyncing-Ship/repos',
#        'events_url': 'https://api.github.com/users/Asyncing-Ship/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Asyncing-Ship/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Asyncing-Ship/turtle_mountain',
#       'description': 'Turtle Mountain Group Project',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain',
#       'forks_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/forks',
#       'keys_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/teams',
#       'hooks_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/events',
#       'assignees_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/tags',
#       'blobs_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/languages',
#       'stargazers_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/subscription',
#       'commits_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/merges',
#       'archive_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/downloads',
#       'issues_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/deployments',
#       'created_at': '2020-07-27T16:09:39Z',
#       'updated_at': '2020-08-17T06:33:08Z',
#       'pushed_at': '2020-08-17T06:33:56Z',
#       'git_url': 'git://github.com/Asyncing-Ship/turtle_mountain.git',
#       'ssh_url': 'git@github.com:Asyncing-Ship/turtle_mountain.git',
#       'clone_url': 'https://github.com/Asyncing-Ship/turtle_mountain.git',
#       'svn_url': 'https://github.com/Asyncing-Ship/turtle_mountain',
#       'homepage': None,
#       'size': 950,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 3,
#       'default_branch': 'develop'}},
#     'base': {'label': 'Asyncing-Ship:develop',
#      'ref': 'develop',
#      'sha': '3229118abe28fa0bc96decedb51b3cca10cef980',
#      'user': {'login': 'Asyncing-Ship',
#       'id': 68861302,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY4ODYxMzAy',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/68861302?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Asyncing-Ship',
#       'html_url': 'https://github.com/Asyncing-Ship',
#       'followers_url': 'https://api.github.com/users/Asyncing-Ship/followers',
#       'following_url': 'https://api.github.com/users/Asyncing-Ship/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Asyncing-Ship/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Asyncing-Ship/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Asyncing-Ship/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Asyncing-Ship/orgs',
#       'repos_url': 'https://api.github.com/users/Asyncing-Ship/repos',
#       'events_url': 'https://api.github.com/users/Asyncing-Ship/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Asyncing-Ship/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 282949224,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyODI5NDkyMjQ=',
#       'name': 'turtle_mountain',
#       'full_name': 'Asyncing-Ship/turtle_mountain',
#       'private': False,
#       'owner': {'login': 'Asyncing-Ship',
#        'id': 68861302,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY4ODYxMzAy',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/68861302?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Asyncing-Ship',
#        'html_url': 'https://github.com/Asyncing-Ship',
#        'followers_url': 'https://api.github.com/users/Asyncing-Ship/followers',
#        'following_url': 'https://api.github.com/users/Asyncing-Ship/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Asyncing-Ship/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Asyncing-Ship/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Asyncing-Ship/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Asyncing-Ship/orgs',
#        'repos_url': 'https://api.github.com/users/Asyncing-Ship/repos',
#        'events_url': 'https://api.github.com/users/Asyncing-Ship/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Asyncing-Ship/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Asyncing-Ship/turtle_mountain',
#       'description': 'Turtle Mountain Group Project',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain',
#       'forks_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/forks',
#       'keys_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/teams',
#       'hooks_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/events',
#       'assignees_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/tags',
#       'blobs_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/languages',
#       'stargazers_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/subscription',
#       'commits_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/merges',
#       'archive_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/downloads',
#       'issues_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/deployments',
#       'created_at': '2020-07-27T16:09:39Z',
#       'updated_at': '2020-08-17T06:33:08Z',
#       'pushed_at': '2020-08-17T06:33:56Z',
#       'git_url': 'git://github.com/Asyncing-Ship/turtle_mountain.git',
#       'ssh_url': 'git@github.com:Asyncing-Ship/turtle_mountain.git',
#       'clone_url': 'https://github.com/Asyncing-Ship/turtle_mountain.git',
#       'svn_url': 'https://github.com/Asyncing-Ship/turtle_mountain',
#       'homepage': None,
#       'size': 950,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 3,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls/247'},
#      'html': {'href': 'https://github.com/Asyncing-Ship/turtle_mountain/pull/247'},
#      'issue': {'href': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues/247'},
#      'comments': {'href': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/issues/247/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls/247/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/pulls/247/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Asyncing-Ship/turtle_mountain/statuses/e93d441f1e910d758ec3f7bbe2d8edef34346b93'}},
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 65,
#     'deletions': 70,
#     'changed_files': 6}},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z',
#   'org': {'id': 68861302,
#    'login': 'Asyncing-Ship',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Asyncing-Ship',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68861302?'}},
#  {'id': '13217355805',
#   'type': 'DeleteEvent',
#   'actor': {'id': 21288589,
#    'login': 'birom',
#    'display_login': 'birom',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/birom',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21288589?'},
#   'repo': {'id': 120743245,
#    'name': 'alv-ch/job-ad-service',
#    'url': 'https://api.github.com/repos/alv-ch/job-ad-service'},
#   'payload': {'ref': 'release.prod-incident-sprint-48-external-job-update',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z',
#   'org': {'id': 7008756,
#    'login': 'alv-ch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/alv-ch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7008756?'}},
#  {'id': '13217355786',
#   'type': 'PushEvent',
#   'actor': {'id': 13942667,
#    'login': 'orgeva',
#    'display_login': 'orgeva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/orgeva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13942667?'},
#   'repo': {'id': 253472367,
#    'name': 'wix-incubator/wix-rest-docs',
#    'url': 'https://api.github.com/repos/wix-incubator/wix-rest-docs'},
#   'payload': {'push_id': 5538891640,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/consent-policy-service',
#    'head': 'da55778e52ae98319f9cef52f183b83a0570fd19',
#    'before': '447f6e803d9093f9caa2e2d652f95b623d69d54e',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z',
#   'org': {'id': 37068588,
#    'login': 'wix-incubator',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wix-incubator',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37068588?'}},
#  {'id': '13217355792',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 255707065,
#    'name': 'jorgebg/airquality',
#    'url': 'https://api.github.com/repos/jorgebg/airquality'},
#   'payload': {'push_id': 5538891670,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/state',
#    'head': 'f6371a231fb01390a0c69a06647a9a9cd58e88bc',
#    'before': 'ec234cd9dd3e0b927f440bf42141869ed242cc1d',
#    'commits': [{'sha': 'f6371a231fb01390a0c69a06647a9a9cd58e88bc',
#      'author': {'email': 'airquality@jorgebg.com', 'name': 'Air Quality Bot'},
#      'message': '10 messages found from 2020-08-17 06:27:20 to 2020-08-17 06:28:50',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jorgebg/airquality/commits/f6371a231fb01390a0c69a06647a9a9cd58e88bc'}]},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355796',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 199205870,
#    'name': 'kldomtbg/RootManager',
#    'url': 'https://api.github.com/repos/kldomtbg/RootManager'},
#   'payload': {'action': 'opened',
#    'number': 42,
#    'pull_request': {'url': 'https://api.github.com/repos/kldomtbg/RootManager/pulls/42',
#     'id': 468621283,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDY4NjIxMjgz',
#     'html_url': 'https://github.com/kldomtbg/RootManager/pull/42',
#     'diff_url': 'https://github.com/kldomtbg/RootManager/pull/42.diff',
#     'patch_url': 'https://github.com/kldomtbg/RootManager/pull/42.patch',
#     'issue_url': 'https://api.github.com/repos/kldomtbg/RootManager/issues/42',
#     'number': 42,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump kotlin_version from 1.3.41 to 1.4.0',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps `kotlin_version` from 1.3.41 to 1.4.0.\nUpdates `kotlin-gradle-plugin` from 1.3.41 to 1.4.0\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/JetBrains/kotlin/releases">kotlin-gradle-plugin\'s releases</a>.</em></p>\n<blockquote>\n<h2>Kotlin 1.4.0</h2>\n<h2>Contents</h2>\n<p>The release contents the JVM version of the Kotlin compiler, and also the Kotlin/Native compiler for the supported platforms: Linux, macOS and Windows.</p>\n<h2>Changelog</h2>\n<h2>1.4.0</h2>\n<h3>Compiler</h3>\n<h4>New Features</h4>\n<ul>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-23729"><code>KT-23729</code></a> Provide a way to generate JVM default method bodies in interfaces delegating to DefaultImpls</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-30330"><code>KT-30330</code></a> Introduce KotlinNothingValueException and throw it instead of NPE on expressions of type Nothing</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-38435"><code>KT-38435</code></a> Support suspend conversion on callable references in JVM backend</li>\n</ul>\n<h4>Fixes</h4>\n<ul>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-35483"><code>KT-35483</code></a> NI: compatibility mode</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-39728"><code>KT-39728</code></a> Declarations from <code>kotlin.reflect</code> resolved to expect-classes even in JVM modules in IDE</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40153"><code>KT-40153</code></a> REPL IDE services completion fails on imports completion</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40404"><code>KT-40404</code></a> Mixed named/positional arguments: argument can be passed twice</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40544"><code>KT-40544</code></a> NI: &quot;TYPE_MISMATCH: Required: MutableList<!-- raw HTML omitted -->&quot; caused by Java interface function</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40555"><code>KT-40555</code></a> NI: Spread operator allows inferred nullable types</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40646"><code>KT-40646</code></a> NI: TYPE_MISMATCH: &quot;inferred type is Unit but Observer<!-- raw HTML omitted --> was expected&quot; caused by LieData.observe inference</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40691"><code>KT-40691</code></a> False positive CAPTURED_VAL_INITIALIZATION with EXACTLY_ONCE contract</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40693"><code>KT-40693</code></a> UnsupportedOperationException: no descriptor for type constructor of (CapturedType(out TResult)..CapturedType(out TResult)?)</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40824"><code>KT-40824</code></a> Usages of a typealias lose nullability and annotations in deserialization</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40843"><code>KT-40843</code></a> Unhandled exception for suspending methods that return Result type</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40869"><code>KT-40869</code></a> Recursion computation inside compiler resolve on a correct code</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40893"><code>KT-40893</code></a> Error &quot;Captured values initialization is forbidden due to possible reassignment&quot; when attempting to use the plusAssign operator with a java list inside an inline function</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40919"><code>KT-40919</code></a> kotlin.collections.ArrayDeque requires an explicit import when compiling with kotlinc 1.4-RC and -language-version 1.3</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40920"><code>KT-40920</code></a> Regression in JvmDefault: incorrect access to missing DefaultImpls on default methods in Java interface overriding Kotlin interface</li>\n<li><a href="https://youtrack.jetbrains.com/issue/KT-40978"><code>KT-40978</code></a> Prohibit using s ...
#     'created_at': '2020-08-17T06:34:04Z',
#     'updated_at': '2020-08-17T06:34:04Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/kldomtbg/RootManager/pulls/42/commits',
#     'review_comments_url': 'https://api.github.com/repos/kldomtbg/RootManager/pulls/42/comments',
#     'review_comment_url': 'https://api.github.com/repos/kldomtbg/RootManager/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/kldomtbg/RootManager/issues/42/comments',
#     'statuses_url': 'https://api.github.com/repos/kldomtbg/RootManager/statuses/bed0c8fdd25766059981cfce2bab24604294d9fd',
#     'head': {'label': 'kldomtbg:dependabot/gradle/kotlin_version-1.4.0',
#      'ref': 'dependabot/gradle/kotlin_version-1.4.0',
#      'sha': 'bed0c8fdd25766059981cfce2bab24604294d9fd',
#      'user': {'login': 'kldomtbg',
#       'id': 53278660,
#       'node_id': 'MDQ6VXNlcjUzMjc4NjYw',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/53278660?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kldomtbg',
#       'html_url': 'https://github.com/kldomtbg',
#       'followers_url': 'https://api.github.com/users/kldomtbg/followers',
#       'following_url': 'https://api.github.com/users/kldomtbg/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kldomtbg/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kldomtbg/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kldomtbg/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kldomtbg/orgs',
#       'repos_url': 'https://api.github.com/users/kldomtbg/repos',
#       'events_url': 'https://api.github.com/users/kldomtbg/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kldomtbg/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 199205870,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTkyMDU4NzA=',
#       'name': 'RootManager',
#       'full_name': 'kldomtbg/RootManager',
#       'private': False,
#       'owner': {'login': 'kldomtbg',
#        'id': 53278660,
#        'node_id': 'MDQ6VXNlcjUzMjc4NjYw',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/53278660?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kldomtbg',
#        'html_url': 'https://github.com/kldomtbg',
#        'followers_url': 'https://api.github.com/users/kldomtbg/followers',
#        'following_url': 'https://api.github.com/users/kldomtbg/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kldomtbg/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kldomtbg/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kldomtbg/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kldomtbg/orgs',
#        'repos_url': 'https://api.github.com/users/kldomtbg/repos',
#        'events_url': 'https://api.github.com/users/kldomtbg/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kldomtbg/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/kldomtbg/RootManager',
#       'description': 'A lib used to access root permission and execute shell command on Android',
#       'fork': True,
#       'url': 'https://api.github.com/repos/kldomtbg/RootManager',
#       'forks_url': 'https://api.github.com/repos/kldomtbg/RootManager/forks',
#       'keys_url': 'https://api.github.com/repos/kldomtbg/RootManager/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kldomtbg/RootManager/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kldomtbg/RootManager/teams',
#       'hooks_url': 'https://api.github.com/repos/kldomtbg/RootManager/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kldomtbg/RootManager/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kldomtbg/RootManager/events',
#       'assignees_url': 'https://api.github.com/repos/kldomtbg/RootManager/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kldomtbg/RootManager/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kldomtbg/RootManager/tags',
#       'blobs_url': 'https://api.github.com/repos/kldomtbg/RootManager/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kldomtbg/RootManager/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kldomtbg/RootManager/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kldomtbg/RootManager/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kldomtbg/RootManager/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kldomtbg/RootManager/languages',
#       'stargazers_url': 'https://api.github.com/repos/kldomtbg/RootManager/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kldomtbg/RootManager/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kldomtbg/RootManager/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kldomtbg/RootManager/subscription',
#       'commits_url': 'https://api.github.com/repos/kldomtbg/RootManager/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kldomtbg/RootManager/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kldomtbg/RootManager/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kldomtbg/RootManager/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kldomtbg/RootManager/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kldomtbg/RootManager/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kldomtbg/RootManager/merges',
#       'archive_url': 'https://api.github.com/repos/kldomtbg/RootManager/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kldomtbg/RootManager/downloads',
#       'issues_url': 'https://api.github.com/repos/kldomtbg/RootManager/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kldomtbg/RootManager/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kldomtbg/RootManager/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kldomtbg/RootManager/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kldomtbg/RootManager/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kldomtbg/RootManager/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kldomtbg/RootManager/deployments',
#       'created_at': '2019-07-27T19:30:12Z',
#       'updated_at': '2019-11-04T10:06:31Z',
#       'pushed_at': '2020-08-17T06:34:04Z',
#       'git_url': 'git://github.com/kldomtbg/RootManager.git',
#       'ssh_url': 'git@github.com:kldomtbg/RootManager.git',
#       'clone_url': 'https://github.com/kldomtbg/RootManager.git',
#       'svn_url': 'https://github.com/kldomtbg/RootManager',
#       'homepage': None,
#       'size': 145,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Kotlin',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'kldomtbg:master',
#      'ref': 'master',
#      'sha': '426b79c7f1fef1ec49be63eb559efce29cf64813',
#      'user': {'login': 'kldomtbg',
#       'id': 53278660,
#       'node_id': 'MDQ6VXNlcjUzMjc4NjYw',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/53278660?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kldomtbg',
#       'html_url': 'https://github.com/kldomtbg',
#       'followers_url': 'https://api.github.com/users/kldomtbg/followers',
#       'following_url': 'https://api.github.com/users/kldomtbg/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kldomtbg/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kldomtbg/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kldomtbg/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kldomtbg/orgs',
#       'repos_url': 'https://api.github.com/users/kldomtbg/repos',
#       'events_url': 'https://api.github.com/users/kldomtbg/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kldomtbg/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 199205870,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTkyMDU4NzA=',
#       'name': 'RootManager',
#       'full_name': 'kldomtbg/RootManager',
#       'private': False,
#       'owner': {'login': 'kldomtbg',
#        'id': 53278660,
#        'node_id': 'MDQ6VXNlcjUzMjc4NjYw',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/53278660?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kldomtbg',
#        'html_url': 'https://github.com/kldomtbg',
#        'followers_url': 'https://api.github.com/users/kldomtbg/followers',
#        'following_url': 'https://api.github.com/users/kldomtbg/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kldomtbg/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kldomtbg/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kldomtbg/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kldomtbg/orgs',
#        'repos_url': 'https://api.github.com/users/kldomtbg/repos',
#        'events_url': 'https://api.github.com/users/kldomtbg/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kldomtbg/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/kldomtbg/RootManager',
#       'description': 'A lib used to access root permission and execute shell command on Android',
#       'fork': True,
#       'url': 'https://api.github.com/repos/kldomtbg/RootManager',
#       'forks_url': 'https://api.github.com/repos/kldomtbg/RootManager/forks',
#       'keys_url': 'https://api.github.com/repos/kldomtbg/RootManager/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kldomtbg/RootManager/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kldomtbg/RootManager/teams',
#       'hooks_url': 'https://api.github.com/repos/kldomtbg/RootManager/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kldomtbg/RootManager/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kldomtbg/RootManager/events',
#       'assignees_url': 'https://api.github.com/repos/kldomtbg/RootManager/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kldomtbg/RootManager/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kldomtbg/RootManager/tags',
#       'blobs_url': 'https://api.github.com/repos/kldomtbg/RootManager/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kldomtbg/RootManager/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kldomtbg/RootManager/git/refs{/sha}',
# ...
#        'events_url': 'https://api.github.com/users/bbq-beets/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/bbq-beets/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/bbq-beets/ForkPRCanary',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary',
#       'forks_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/forks',
#       'keys_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/teams',
#       'hooks_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/events',
#       'assignees_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/tags',
#       'blobs_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/languages',
#       'stargazers_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/subscription',
#       'commits_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/merges',
#       'archive_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/downloads',
#       'issues_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/deployments',
#       'created_at': '2020-07-05T02:42:04Z',
#       'updated_at': '2020-08-01T14:31:49Z',
#       'pushed_at': '2020-08-17T06:24:37Z',
#       'git_url': 'git://github.com/bbq-beets/ForkPRCanary.git',
#       'ssh_url': 'git@github.com:bbq-beets/ForkPRCanary.git',
#       'clone_url': 'https://github.com/bbq-beets/ForkPRCanary.git',
#       'svn_url': 'https://github.com/bbq-beets/ForkPRCanary',
#       'homepage': None,
#       'size': 44,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 29,
#       'license': None,
#       'forks': 2,
#       'open_issues': 29,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/pulls/6320'},
#      'html': {'href': 'https://github.com/bbq-beets/ForkPRCanary/pull/6320'},
#      'issue': {'href': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/issues/6320'},
#      'comments': {'href': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/issues/6320/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/pulls/6320/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/pulls/6320/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/bbq-beets/ForkPRCanary/statuses/7df2f3ec736193fdaa430703212ed371dc9ecb58'}},
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 4,
#     'additions': 3,
#     'deletions': 60,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z',
#   'org': {'id': 33435682,
#    'login': 'bbq-beets',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bbq-beets',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33435682?'}},
#  {'id': '13217355736',
#   'type': 'PushEvent',
#   'actor': {'id': 41498766,
#    'login': 'beckyphan',
#    'display_login': 'beckyphan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/beckyphan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41498766?'},
#   'repo': {'id': 168906495,
#    'name': 'beckyphan/learn-co-sandbox',
#    'url': 'https://api.github.com/repos/beckyphan/learn-co-sandbox'},
#   'payload': {'push_id': 5538891631,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '0a0f27758f2fee368b8fbd597d60658730d21ab8',
#    'before': '1973940620ebb47c36e9a75aab06082cc6d96796',
#    'commits': [{'sha': '0a0f27758f2fee368b8fbd597d60658730d21ab8',
#      'author': {'email': 'beckyphan@live.com', 'name': 'Becky Phan'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/beckyphan/learn-co-sandbox/commits/0a0f27758f2fee368b8fbd597d60658730d21ab8'}]},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355744',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 237911468,
#    'name': 'mfmfuyu/mastodon',
#    'url': 'https://api.github.com/repos/mfmfuyu/mastodon'},
#   'payload': {'ref': 'dependabot/bundler/rubocop-0.89.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Your self-hosted, globally interconnected microblogging community',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355729',
#   'type': 'PushEvent',
#   'actor': {'id': 69368729,
#    'login': 'YevBor',
#    'display_login': 'YevBor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YevBor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69368729?'},
#   'repo': {'id': 287947074,
#    'name': 'YevBor/how-to-learn',
#    'url': 'https://api.github.com/repos/YevBor/how-to-learn'},
#   'payload': {'push_id': 5538891636,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '73f756983fe991fab88141b511c683cab09d63ea',
#    'before': '689b75de6525e0e3a893d18009c0994d8818afa4',
#    'commits': [{'sha': '73f756983fe991fab88141b511c683cab09d63ea',
#      'author': {'email': 'yev.bor@yandex.ru', 'name': 'Yevgeniy Borisovsky'},
#      'message': 'html modified',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/YevBor/how-to-learn/commits/73f756983fe991fab88141b511c683cab09d63ea'}]},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355724',
#   'type': 'PushEvent',
#   'actor': {'id': 11512490,
#    'login': 'lamondlu',
#    'display_login': 'lamondlu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lamondlu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11512490?'},
#   'repo': {'id': 287857946,
#    'name': 'lamondlu/Lamond.SSF',
#    'url': 'https://api.github.com/repos/lamondlu/Lamond.SSF'},
#   'payload': {'push_id': 5538891625,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd8c49cfa80f42c0317ee78ec2c6a5d54b3210457',
#    'before': '5bad736cc0daf98e76cf1ecd1d766bf37737da53',
#    'commits': [{'sha': 'd8c49cfa80f42c0317ee78ec2c6a5d54b3210457',
#      'author': {'email': 'lunan@shintechchina.com', 'name': 'Lamond Lu'},
#      'message': 'Clean up the code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lamondlu/Lamond.SSF/commits/d8c49cfa80f42c0317ee78ec2c6a5d54b3210457'}]},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355727',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 588407,
#    'login': 'm-kuhn',
#    'display_login': 'm-kuhn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/m-kuhn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/588407?'},
#   'repo': {'id': 46345984,
#    'name': 'opengisch/QField-docs',
#    'url': 'https://api.github.com/repos/opengisch/QField-docs'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/opengisch/QField-docs/issues/54',
#     'repository_url': 'https://api.github.com/repos/opengisch/QField-docs',
#     'labels_url': 'https://api.github.com/repos/opengisch/QField-docs/issues/54/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/opengisch/QField-docs/issues/54/comments',
#     'events_url': 'https://api.github.com/repos/opengisch/QField-docs/issues/54/events',
#     'html_url': 'https://github.com/opengisch/QField-docs/pull/54',
#     'id': 620828867,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDE5OTk3OTA5',
#     'number': 54,
#     'title': 'change Field type to Widget type',
#     'user': {'login': 'soester',
#      'id': 28543978,
#      'node_id': 'MDQ6VXNlcjI4NTQzOTc4',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/28543978?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/soester',
#      'html_url': 'https://github.com/soester',
#      'followers_url': 'https://api.github.com/users/soester/followers',
#      'following_url': 'https://api.github.com/users/soester/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/soester/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/soester/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/soester/subscriptions',
#      'organizations_url': 'https://api.github.com/users/soester/orgs',
#      'repos_url': 'https://api.github.com/users/soester/repos',
#      'events_url': 'https://api.github.com/users/soester/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/soester/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-05-19T09:35:48Z',
#     'updated_at': '2020-08-17T06:34:04Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/opengisch/QField-docs/pulls/54',
#      'html_url': 'https://github.com/opengisch/QField-docs/pull/54',
#      'diff_url': 'https://github.com/opengisch/QField-docs/pull/54.diff',
#      'patch_url': 'https://github.com/opengisch/QField-docs/pull/54.patch'},
#     'body': 'Would fix:\r\nhttps://github.com/opengisch/QField/issues/1026\r\n\r\nJust checked for the Range widget maybe there is more to be adapded? The documentation seems to rely on an older qgis version?',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/opengisch/QField-docs/issues/comments/674689059',
#     'html_url': 'https://github.com/opengisch/QField-docs/pull/54#issuecomment-674689059',
#     'issue_url': 'https://api.github.com/repos/opengisch/QField-docs/issues/54',
#     'id': 674689059,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY3NDY4OTA1OQ==',
#     'user': {'login': 'm-kuhn',
#      'id': 588407,
#      'node_id': 'MDQ6VXNlcjU4ODQwNw==',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/588407?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/m-kuhn',
#      'html_url': 'https://github.com/m-kuhn',
#      'followers_url': 'https://api.github.com/users/m-kuhn/followers',
#      'following_url': 'https://api.github.com/users/m-kuhn/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/m-kuhn/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/m-kuhn/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/m-kuhn/subscriptions',
#      'organizations_url': 'https://api.github.com/users/m-kuhn/orgs',
#      'repos_url': 'https://api.github.com/users/m-kuhn/repos',
#      'events_url': 'https://api.github.com/users/m-kuhn/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/m-kuhn/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-08-17T06:34:04Z',
#     'updated_at': '2020-08-17T06:34:04Z',
#     'author_association': 'MEMBER',
#     'body': "I don't think it applies any more.\r\nIf you have a TextEdit with a numerical field, it only accepts numbers, correct @signedav ?\r\nWe could still adjust the title (Field Type -> Widget Type) if we want to.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z',
#   'org': {'id': 8892251,
#    'login': 'opengisch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/opengisch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8892251?'}},
#  {'id': '13217355725',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 102260448,
#    'name': 'd-mato/liblog',
#    'url': 'https://api.github.com/repos/d-mato/liblog'},
#   'payload': {'ref': 'dependabot/bundler/ridgepole-0.8.10',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'},
#  {'id': '13217355723',
#   'type': 'DeleteEvent',
#   'actor': {'id': 679017,
#    'login': 'JrGoodle',
#    'display_login': 'JrGoodle',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JrGoodle',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/679017?'},
#   'repo': {'id': 38169614,
#    'name': 'JrGoodle/sasha',
#    'url': 'https://api.github.com/repos/JrGoodle/sasha'},
#   'payload': {'ref': 'prune_branch',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-17T06:34:05Z'}]

# %% [markdown]
# * r.text是字串
# * json.loads(r.text)是列表

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# {'all': [{'_id': '5894af975cdc7400113ef7f9',
#    'text': 'The technical term for a cat’s hairball is a bezoar.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b0c5e3e7ab3c50014df65fe',
#    'text': 'People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00a7e0aac31001185ed19',
#    'text': "A cat's cerebral cortex (the part of the brain in charge of cognitive information processing) has 300 million neurons, compared with a dog's 160 million.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b1f0aac31001185ed1e',
#    'text': 'In the 15th century, Pope Innocent VIII began ordering the killing of cats, pronouncing them demonic.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58f89cff11658e00113ddd26',
#    'text': 'Cats love to eat olives or for that matter anything preserved in brine.',
#    'type': 'cat',
#    'user': {'_id': '58f89c8d11658e00113ddd24',
#     'name': {'first': 'Malvika', 'last': 'Tewari'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
# ...
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e83ff18f53272001515690c',
#    'type': 'cat',
#    'text': 'Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e80e7cc2d4b850015003072',
#    'type': 'cat',
#    'text': 'Cats can climb on trees faster than squirels.',
#    'user': {'_id': '5e80e6c72d4b85001500306e',
#     'name': {'first': 'Łukasz', 'last': 'Wiktorko'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eafdaf354ad960017b3703d',
#    'type': 'cat',
#    'text': 'Yjyyu.',
#    'user': {'_id': '5eafdad954ad960017b37038',
#     'name': {'first': 'Lulu', 'last': 'Dauphin'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ebbf5dd8046d00017776020',
#    'type': 'cat',
#    'text': 'Cats are fat, sometimes.',
#    'user': {'_id': '5ebbf5cd8046d0001777601f',
#     'name': {'first': 'George', 'last': 'Miguel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec4aad30c796a00174d7b26',
#    'type': 'cat',
#    'text': 'Sss.',
#    'user': {'_id': '5ec4a7d60c796a00174d7b25',
#     'name': {'first': 'Minh', 'last': 'Nguyễn'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec93d1de11bba0017c67e19',
#    'type': 'cat',
#    'text': 'In a sense, cats can see in the dark.',
#    'user': {'_id': '5ec93c89e11bba0017c67e18',
#     'name': {'first': 'Mandy', 'last': 'c'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb032ab0d92c0017cab214',
#    'type': 'cat',
#    'text': 'Cats are the best pets.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb0333b0d92c0017cab215',
#    'type': 'cat',
#    'text': 'Hello cats.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecdda946253f20017f53ec5',
#    'type': 'cat',
#    'text': 'Cats love womans, dog loves mans.',
#    'user': {'_id': '5ecdda686253f20017f53ec4',
#     'name': {'first': 'Jorge Alberto', 'last': 'Gil Rendon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece7253a0d2ec00178ae28c',
#    'type': 'cat',
#    'text': 'Cat is cat.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece9fa9a0d2ec00178ae28e',
#    'type': 'cat',
#    'text': 'Z.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ed11e643c15f700172e3856',
#    'type': 'cat',
#    'text': 'Los gatos tienen más huesos que los seres humanos, nos ganan por 24.',
#    'user': {'_id': '5ed11e353c15f700172e3855',
#     'name': {'first': 'Luciano', 'last': 'Garrido Sepulveda'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eddfb501ed5570017aaf3b9',
#    'type': 'cat',
#    'text': 'Take a try.',
#    'user': {'_id': '5eddfb351ed5570017aaf3b8',
#     'name': {'first': 'calix', 'last': 'cheng'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eebc851515a030017471024',
#    'type': 'cat',
#    'text': 'Cats are cats.',
#    'user': {'_id': '5eebc848515a030017471023',
#     'name': {'first': 'Ricky', 'last': 'Chon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ef556dff61f300017030d4c',
#    'type': 'cat',
#    'text': 'Lucy, the oldest cat ever, lived to be 39 years old which is equivalent to 172 cat years.',
#    'user': {'_id': '5e1a9b981fd6150015fa736f',
#     'name': {'first': 'Andrew', 'last': 'Pobrica'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ef5bbdbf61f300017030d4f',
#    'type': 'cat',
#    'text': 'Fdfd.',
#    'user': {'_id': '5ef5bbcdf61f300017030d4e',
#     'name': {'first': 'Touch', 'last': 'Akhil'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f0371215ac1ed0017c647a9',
#    'type': 'cat',
#    'text': 'Cxcbc.',
#    'user': {'_id': '5f03708f5ac1ed0017c647a8',
#     'name': {'first': 'Marylange', 'last': 'Souza'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f03712d5ac1ed0017c647aa',
#    'type': 'cat',
#    'text': 'Jfhfhf.',
#    'user': {'_id': '5f03708f5ac1ed0017c647a8',
#     'name': {'first': 'Marylange', 'last': 'Souza'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f0a15090fc09b00174aec96',
#    'type': 'cat',
#    'text': '1123405258.',
#    'user': {'_id': '5f0a15010fc09b00174aec95',
#     'name': {'first': 'nelson enrique', 'last': 'redondo b'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f119d925ada6000174e785c',
#    'type': 'cat',
#    'text': 'Cat are cute.',
#    'user': {'_id': '5f119d3e5ada6000174e785b',
#     'name': {'first': 'Prof', 'last': 'MATH DZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f27be5f1fb098001709b5fb',
#    'type': 'cat',
#    'text': 'Hello.',
#    'user': {'_id': '5f27bda31fb098001709b5fa',
#     'name': {'first': 'Tiến', 'last': 'Lê Đức'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f2c80477329f500172d13bb',
#    'type': 'cat',
#    'text': 'Potato.',
#    'user': {'_id': '5f2c649a7329f500172d13ba',
#     'name': {'first': 'Black', 'last': 'Rose'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f2ca50758ea8e0017ed1266',
#    'type': 'cat',
#    'text': 'Testing.',
#    'user': {'_id': '5f2c649a7329f500172d13ba',
#     'name': {'first': 'Black', 'last': 'Rose'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f2ddb9358ea8e0017ed1268',
#    'type': 'cat',
#    'text': 'Zoe.',
#    'user': {'_id': '5f2ddb7e58ea8e0017ed1267',
#     'name': {'first': 'Sebastian', 'last': 'Leal'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ea7496761cd4d0017498a94',
#    'type': 'cat',
#    'text': 'Ancient sailors believed that cats were magic and would often risk their own lives, even in an "every man for himself" situation, to save a cat from a sinking ship. All ships had at least one ship\'s cat as cats would eat the rats that have always plagued ships. The ship\'s cat would often be given a rank and sailors would generally take excessively good care of their cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eaafca69105ce00177573de',
#    'type': 'cat',
#    'text': 'Cats sleep most of the time.',
#    'user': {'_id': '5ea977d1cd53d20017d7d8b2',
#     'name': {'first': 'Quang', 'last': 'Pham'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f351d93c7b64f001735a0fb',
#    'type': 'cat',
#    'text': 'De.',
#    'user': {'_id': '5f351d81c7b64f001735a0fa',
#     'name': {'first': 'eyyüp', 'last': 'bağdaş'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f35a5fdc7b64f001735a1a2',
#    'type': 'cat',
#    'text': 'Asdfasfdafa.',
#    'user': {'_id': '5f2c649a7329f500172d13ba',
#     'name': {'first': 'Black', 'last': 'Rose'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f35a652c7b64f001735a1a3',
#    'type': 'cat',
#    'text': 'Asdfsafsasaddsasasfddsa.',
#    'user': {'_id': '5f2c649a7329f500172d13ba',
#     'name': {'first': 'Black', 'last': 'Rose'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
